# %%
class Human:

  def __init__(self, name, age,):
    self.name = name
    self.age = age

  def printinfo(self):
    print(self.name)
    print(self.age)

personal_data = Human("侍太郎", 29)

personal_data.printinfo()
# Out:
# 侍太郎
# 29
